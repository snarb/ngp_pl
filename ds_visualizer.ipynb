# %%
import os
import glob
import imageio
import numpy as np
import cv2
import pathlib
import matplotlib.pyplot as plt

# %%
root_dir = '/home/ubuntu/repos/vid_ds/cut_roasted_beef/'
root_dir = '/home/ubuntu/repos/vid_ds/coffee_martini/'

# %%
img_paths = sorted(list(pathlib.Path(root_dir).glob('*.mp4')))

# %%
img_paths[0]
# Out:
# PosixPath('/home/ubuntu/repos/vid_ds/cut_roasted_beef/cam00.mp4')

# %%
for img_path in img_paths:
    cap = cv2.VideoCapture(str(img_path))
    flag, frame = cap.read()
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    plt.imshow(frame)
    plt.show()
